# %%
import csv
import matplotlib.pyplot as plt

# 文件路径
file_paths = ['hat_capacity.csv', 'ada_capacity.csv', "ada_random_capacity.csv", "ada_cons_alpha_capacity.csv", 'ada_cons_1_capacity.csv', ]

legend_list = ['HAT', 'AdaHAT', "HAT-random", "HAT-const-alpha", 'HAT-const-1', ]

# 存储所有数据的列表
data = []

# 加载数据
for i, file_path in enumerate(file_paths):
    with open(file_path, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # 跳过标题行
        capacity_data = [float(row[0]) for row in reader]
        src.data.extend([(i, capacity) for capacity in capacity_data])

# 绘制折线图
plt.figure(figsize=(10, 7))
for i in range(0, 5):
    capacities = [d[1] for d in data if d[0] == i]
    plt.plot(capacities, label=legend_list[i], linewidth=5)

plt.yscale('log')  # 使用对数刻度
plt.ylabel('NC', fontsize=24)
plt.xlabel('Iteration', fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)  # 设置纵坐标刻度
plt.legend(fontsize=17)

# 调整坐标轴线宽
plt.gca().spines['bottom'].set_linewidth(3)
plt.gca().spines['left'].set_linewidth(3)

# 删除小刻度
plt.tick_params(axis='both', which='both', length=0)

plt.tight_layout()

plt.savefig('plot.pdf', format='pdf')

plt.show()
