# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# metric = "test_metrics"
# column_name = "test/acc/ave"

# metric = "test_forgetting_ratio"
# column_name = "test/fr/ave"


# metric = "test_bwt"
# column_name = "bwt"

# metric = "test_fwt"
# column_name = "fwt"



# metric = "test_fm"
# column_name = "fm"



metric = "test_im"
column_name = "im"


mean_or_std = "mean"
# mean_or_std = "std"


# csv_path_list = [f"../../logs_saved/s20/HAT_1/runs/s{i}/csv/{metric}.csv" for i in range(1,11)]

expr_names = [
    "Finetuning_1",
    "LwF_1",
    "EWC_1", 
    "HAT_1", 
    "ada", 
    "ada_ave", 
    "ada_cons_1",
        "ada_cons_alpha",

    "ada_prob", 
    "ada_ave_prob", 
    "ada_cons_alpha_all",
    "ada_random",
        "ada_random_all",

    "ada_reg_1",
    "ada_reg_0",
        "ada_reg_09",

    "ada_sum_1",
    "ada_sum_t",
    ]

csv_path_list = [f"../../logs_saved/pmnist/{n}/runs/{metric}_{mean_or_std}.csv"
for n in expr_names]

# %%
for n,csv_path in zip(expr_names,csv_path_list):
 # read csv

    df = pd.read_csv(csv_path)
    print(n, round(df.at[19, column_name], 4))
    
    





# df_joint = pd.read_csv(jDoint_csv_path)
# df_joint = pd.read_csv(random_csv_path)




# calculate
   
    
# write
# output_csv_path
# Out:
# Finetuning_1 -0.0208
# LwF_1 0.0033
# EWC_1 0.0817
# HAT_1 0.4073
# ada 0.0238
# ada_ave -0.0085
# ada_cons_1 -0.0096
# ada_cons_alpha 0.406
# ada_prob 0.063
# ada_ave_prob 0.0019
# ada_cons_alpha_all -0.0002
# ada_random 0.4073
# ada_random_all -0.0069
# ada_reg_1 0.0575
# ada_reg_0 0.0045
# ada_reg_09 0.052
# ada_sum_1 -0.0071
# ada_sum_t 0.0388
