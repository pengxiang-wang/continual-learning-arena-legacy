# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# metric = "test_metrics"
# column_name = "test/acc/ave"

# metric = "test_forgetting_ratio"
# column_name = "test/fr/ave"


# metric = "test_bwt"
# column_name = "bwt"

metric = "test_fwt"
column_name = "fwt"



# metric = "test_fm"
# column_name = "fm"



# metric = "test_im"
# column_name = "im"


mean_or_std = "mean"
# mean_or_std = "std"

# %%
# csv_path_list = [f"../../logs_saved/s20/HAT_1/runs/s{i}/csv/{metric}.csv" for i in range(1,11)]

expr_names = [
    "Finetuning_2",
    "LwF_2",
    #"EWC_2", 
    "HAT_2", 
    "ada_2", 
    "ada_cons_1_2",
        "ada_cons_alpha_2",
    "ada_random_2",
    
    "Finetuning_4",
    "LwF_4",
    "EWC_4", 
    "HAT_4", 
    "ada_4", 
    "ada_cons_1_4",
        "ada_cons_alpha_4",
    "ada_random_4",
    
    
    "Finetuning_1",
    "LwF_1",
    "EWC_1", 
    "HAT_1", 
    "ada", 
    "ada_ave", 
    "ada_cons_1",
        "ada_cons_alpha",

    "ada_prob", 
    "ada_ave_prob", 
    "ada_cons_alpha_all",
    "ada_random",
        "ada_random_all",

    "ada_reg_1",
    "ada_reg_0",
        "ada_reg_09",

    "ada_sum_1",
    "ada_sum_t",
]


# csv_path_list = [f"../../logs_saved/pmnist/{n}/runs/{metric}_{mean_or_std}.csv"
# for n in expr_names]

csv_path_list = [f"../../logs/{n}/runs/{metric}_{mean_or_std}.csv"
for n in expr_names]

# %%
for n,csv_path in zip(expr_names,csv_path_list):
 # read csv
    if os.path.exists(csv_path):

        df = pd.read_csv(csv_path)
        print(n, round(df.at[19, column_name] * 100, 2), "%")
    
    





# df_joint = pd.read_csv(jDoint_csv_path)
# df_joint = pd.read_csv(random_csv_path)




# calculate
   
    
# write
# output_csv_path
# Out:
# Finetuning_2 64.42 %
# LwF_2 62.74 %
# HAT_2 52.06 %
# ada_2 57.09 %
# ada_cons_1_2 56.94 %
# ada_cons_alpha_2 48.76 %
# ada_random_2 50.87 %
# Finetuning_4 53.1 %
# LwF_4 57.61 %
# HAT_4 53.11 %
# ada_4 56.33 %
# ada_cons_1_4 56.3 %
# ada_cons_alpha_4 51.86 %
# ada_random_4 52.76 %
